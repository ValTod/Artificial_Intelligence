# %%
import pandas as pd
import numpy as np
import io
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
iris_set = pd.read_csv('iris/iris.data', encoding='unicode_escape')

# %%
iris_set
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris_set.columns = ['sepal_length', 'sepal_width', 'petal_width', 'petal_length', 'class']

# %%
iris_set
# Out:
#      sepal_length  sepal_width  petal_width  petal_length           class
# 0             4.9          3.0          1.4           0.2     Iris-setosa
# 1             4.7          3.2          1.3           0.2     Iris-setosa
# 2             4.6          3.1          1.5           0.2     Iris-setosa
# 3             5.0          3.6          1.4           0.2     Iris-setosa
# 4             5.4          3.9          1.7           0.4     Iris-setosa
# ..            ...          ...          ...           ...             ...
# 144           6.7          3.0          5.2           2.3  Iris-virginica
# 145           6.3          2.5          5.0           1.9  Iris-virginica
# 146           6.5          3.0          5.2           2.0  Iris-virginica
# 147           6.2          3.4          5.4           2.3  Iris-virginica
# 148           5.9          3.0          5.1           1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris_set['class'].value_counts()
# Out:
# class
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: count, dtype: int64

# %%
len(iris_set['class'].unique())
# Out:
# 3

# %%
sepal_length_45_10 = iris_set['sepal_length'].where((iris_set['sepal_length'] > 4.5) & (iris_set['sepal_length'] < 10))

# %%
print(sepal_length_45_10)
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal_length, Length: 149, dtype: float64

# %%
average_sepal_length_total = iris_set['sepal_length'].mean()
average_sepal_length_total
# Out:
# 5.8483221476510066

# %%
red =  pd.read_csv('vine/winequality-red.csv', sep=';', encoding='unicode_escape')

# %%
white =  pd.read_csv('vine/winequality-white.csv', sep=';', encoding='unicode_escape')

# %%
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_quality = white["quality"].mean()
white_quality
# Out:
# 5.87790935075541

# %%
white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
red_quality = red["quality"].mean()
red_quality
# Out:
# 5.6360225140712945

# %%
red_correlation = red['alcohol'].corr(red['quality'])
red_correlation_rounded = round(red_correlation, 2)
print(red_correlation_rounded)
# Out:
# 0.48

# %%
white_correlation = white['alcohol'].corr(white['quality'])
white_correlation_rounded = round(white_correlation, 2)
print(white_correlation_rounded)
# Out:
# 0.44
